# %%
import zipfile
import itertools
import string

print("\n\nStart.........\n\n")

# Create a list of characters to use in the password
characters = string.ascii_lowercase + string.digits

# Define the ZIP file to be opened
zip_file_path = 'a.zip'

# Function to generate all possible passwords
def generate_passwords(max_length):
    for length in range(1, max_length + 1):
        for password in itertools.product(characters, repeat=length):
            yield ''.join(password)

# Open the ZIP file
with zipfile.ZipFile(zip_file_path) as the_zip_package:
    found_password = False
    for current_password in generate_passwords(6):
        try:
            print(f"Trying to extract '{the_zip_package.filename}' with the password '{current_password}'")
            the_zip_package.extractall(pwd=current_password.encode())
            found_password = True
            print(f"\n\nThe correct password is '{current_password}'.")
            break
        except (RuntimeError, zipfile.BadZipFile) as e:
            print(f"'{current_password}' is not the correct password", end='\n\n')

    if not found_password:
        print("\n\nNone of the generated passwords is correct.")

print("\n\nEnd.......\n\n")
# Out:
# Start.........
#
#
# Trying to extract 'a.zip' with the password 'a'
# 'a' is not the correct password
#
# Trying to extract 'a.zip' with the password 'b'
# 'b' is not the correct password
#
# Trying to extract 'a.zip' with the password 'c'
# 'c' is not the correct password
#
# Trying to extract 'a.zip' with the password 'd'
# 'd' is not the correct password
#
# Trying to extract 'a.zip' with the password 'e'
# 'e' is not the correct password
#
# Trying to extract 'a.zip' with the password 'f'
# 'f' is not the correct password
#
# Trying to extract 'a.zip' with the password 'g'
# 'g' is not the correct password
#
# Trying to extract 'a.zip' with the password 'h'
# 'h' is not the correct password
#
# Trying to extract 'a.zip' with the password 'i'
# 'i' is not the correct password
#
# Trying to extract 'a.zip' with the password 'j'
# 'j' is not the correct password
#
# Trying to extract 'a.zip' with the password 'k'
# 'k' is not the correct password
#
# Trying to extract 'a.zip' with the password 'l'
# 'l' is not the correct password
#
# Trying to extract 'a.zip' with the password 'm'
# 'm' is not the correct password
#
# Trying to extract 'a.zip' with the password 'n'
# 'n' is not the correct password
#
# Trying to extract 'a.zip' with the password 'o'
# 'o' is not the correct password
#
# Trying to extract 'a.zip' with the password 'p'
# 'p' is not the correct password
#
# Trying to extract 'a.zip' with the password 'q'
# 'q' is not the correct password
#
# Trying to extract 'a.zip' with the password 'r'
# 'r' is not the correct password
#
# Trying to extract 'a.zip' with the password 's'
# 's' is not the correct password
#
# Trying to extract 'a.zip' with the password 't'
# 't' is not the correct password
#
# Trying to extract 'a.zip' with the password 'u'
# 'u' is not the correct password
#
# Trying to extract 'a.zip' with the password 'v'
# 'v' is not the correct password
#
# Trying to extract 'a.zip' with the password 'w'
# 'w' is not the correct password
#
# Trying to extract 'a.zip' with the password 'x'
# 'x' is not the correct password
#
# Trying to extract 'a.zip' with the password 'y'
# 'y' is not the correct password
#
# Trying to extract 'a.zip' with the password 'z'
# 'z' is not the correct password
#
# Trying to extract 'a.zip' with the password '0'
# '0' is not the correct password
#
# Trying to extract 'a.zip' with the password '1'
# '1' is not the correct password
#
# Trying to extract 'a.zip' with the password '2'
# '2' is not the correct password
#
# Trying to extract 'a.zip' with the password '3'
# '3' is not the correct password
#
# Trying to extract 'a.zip' with the password '4'
# '4' is not the correct password
#
# Trying to extract 'a.zip' with the password '5'
# '5' is not the correct password
#
# Trying to extract 'a.zip' with the password '6'
# '6' is not the correct password
#
# Trying to extract 'a.zip' with the password '7'
# '7' is not the correct password
#
# Trying to extract 'a.zip' with the password '8'
# '8' is not the correct password
#
# Trying to extract 'a.zip' with the password '9'
#
#
# The correct password is '9'.
#
#
# End.......

# %%
import zipfile
import itertools
import string

print("\n\nStart.........\n\n")

# Create a list of characters to use in the password
characters = string.ascii_lowercase + string.digits

# Define the ZIP file to be opened
zip_file_path = 'b.zip'

# Function to generate all possible passwords
def generate_passwords(max_length):
    for length in range(1, max_length + 1):
        for password in itertools.product(characters, repeat=length):
            yield ''.join(password)

# Open the ZIP file
with zipfile.ZipFile(zip_file_path) as the_zip_package:
    found_password = False
    for current_password in generate_passwords(6):
        try:
            print(f"Trying to extract '{the_zip_package.filename}' with the password '{current_password}'")
            the_zip_package.extractall(pwd=current_password.encode())
            found_password = True
            print(f"\n\nThe correct password is '{current_password}'.")
            break
        except (RuntimeError, zipfile.BadZipFile) as e:
            print(f"'{current_password}' is not the correct password", end='\n\n')

    if not found_password:
        print("\n\nNone of the generated passwords is correct.")

print("\n\nEnd.......\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# '0qs' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qt'
# '0qt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qu'
# '0qu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qv'
# '0qv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qw'
# '0qw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qx'
# '0qx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qy'
# '0qy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0qz'
# '0qz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q0'
# '0q0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q1'
# '0q1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q2'
# '0q2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q3'
# '0q3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q4'
# '0q4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q5'
# '0q5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q6'
# '0q6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q7'
# '0q7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q8'
# '0q8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0q9'
# '0q9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ra'
# '0ra' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rb'
# '0rb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rc'
# '0rc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rd'
# '0rd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0re'
# '0re' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rf'
# '0rf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rg'
# '0rg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rh'
# '0rh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ri'
# '0ri' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rj'
# '0rj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rk'
# '0rk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rl'
# '0rl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rm'
# '0rm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rn'
# '0rn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ro'
# '0ro' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rp'
# '0rp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rq'
# '0rq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rr'
# '0rr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rs'
# '0rs' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rt'
# '0rt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ru'
# '0ru' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rv'
# '0rv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rw'
# '0rw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rx'
# '0rx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ry'
# '0ry' is not the correct password
#
# Trying to extract 'b.zip' with the password '0rz'
# '0rz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r0'
# '0r0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r1'
# '0r1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r2'
# '0r2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r3'
# '0r3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r4'
# '0r4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r5'
# '0r5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r6'
# '0r6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r7'
# '0r7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r8'
# '0r8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0r9'
# '0r9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sa'
# '0sa' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sb'
# '0sb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sc'
# '0sc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sd'
# '0sd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0se'
# '0se' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sf'
# '0sf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sg'
# '0sg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sh'
# '0sh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0si'
# '0si' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sj'
# '0sj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sk'
# '0sk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sl'
# '0sl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sm'
# '0sm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sn'
# '0sn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0so'
# '0so' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sp'
# '0sp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sq'
# '0sq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sr'
# '0sr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ss'
# '0ss' is not the correct password
#
# Trying to extract 'b.zip' with the password '0st'
# '0st' is not the correct password
#
# Trying to extract 'b.zip' with the password '0su'
# '0su' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sv'
# '0sv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sw'
# '0sw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sx'
# '0sx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sy'
# '0sy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0sz'
# '0sz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s0'
# '0s0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s1'
# '0s1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s2'
# '0s2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s3'
# '0s3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s4'
# '0s4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s5'
# '0s5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s6'
# '0s6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s7'
# '0s7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s8'
# '0s8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0s9'
# '0s9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ta'
# '0ta' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tb'
# '0tb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tc'
# '0tc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0td'
# '0td' is not the correct password
#
# Trying to extract 'b.zip' with the password '0te'
# '0te' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tf'
# '0tf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tg'
# '0tg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0th'
# '0th' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ti'
# '0ti' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tj'
# '0tj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tk'
# '0tk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tl'
# '0tl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tm'
# '0tm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tn'
# '0tn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0to'
# '0to' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tp'
# '0tp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tq'
# '0tq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tr'
# '0tr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ts'
# '0ts' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tt'
# '0tt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tu'
# '0tu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tv'
# '0tv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tw'
# '0tw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tx'
# '0tx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ty'
# '0ty' is not the correct password
#
# Trying to extract 'b.zip' with the password '0tz'
# '0tz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t0'
# '0t0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t1'
# '0t1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t2'
# '0t2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t3'
# '0t3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t4'
# '0t4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t5'
# '0t5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t6'
# '0t6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t7'
# '0t7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t8'
# '0t8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0t9'
# '0t9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ua'
# '0ua' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ub'
# '0ub' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uc'
# '0uc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ud'
# '0ud' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ue'
# '0ue' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uf'
# '0uf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ug'
# '0ug' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uh'
# '0uh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ui'
# '0ui' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uj'
# '0uj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uk'
# '0uk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ul'
# '0ul' is not the correct password
#
# Trying to extract 'b.zip' with the password '0um'
# '0um' is not the correct password
#
# Trying to extract 'b.zip' with the password '0un'
# '0un' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uo'
# '0uo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0up'
# '0up' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uq'
# '0uq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ur'
# '0ur' is not the correct password
#
# Trying to extract 'b.zip' with the password '0us'
# '0us' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ut'
# '0ut' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uu'
# '0uu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uv'
# '0uv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uw'
# '0uw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ux'
# '0ux' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uy'
# '0uy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0uz'
# '0uz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u0'
# '0u0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u1'
# '0u1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u2'
# '0u2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u3'
# '0u3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u4'
# '0u4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u5'
# '0u5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u6'
# '0u6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u7'
# '0u7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u8'
# '0u8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0u9'
# '0u9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0va'
# '0va' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vb'
# '0vb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vc'
# '0vc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vd'
# '0vd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ve'
# '0ve' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vf'
# '0vf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vg'
# '0vg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vh'
# '0vh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vi'
# '0vi' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vj'
# '0vj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vk'
# '0vk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vl'
# '0vl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vm'
# '0vm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vn'
# '0vn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vo'
# '0vo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vp'
# '0vp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vq'
# '0vq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vr'
# '0vr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vs'
# '0vs' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vt'
# '0vt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vu'
# '0vu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vv'
# '0vv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vw'
# '0vw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vx'
# '0vx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vy'
# '0vy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0vz'
# '0vz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v0'
# '0v0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v1'
# '0v1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v2'
# '0v2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v3'
# '0v3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v4'
# '0v4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v5'
# '0v5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v6'
# '0v6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v7'
# '0v7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v8'
# '0v8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0v9'
# '0v9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wa'
# '0wa' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wb'
# '0wb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wc'
# '0wc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wd'
# '0wd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0we'
# '0we' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wf'
# '0wf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wg'
# '0wg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wh'
# '0wh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wi'
# '0wi' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wj'
# '0wj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wk'
# '0wk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wl'
# '0wl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wm'
# '0wm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wn'
# '0wn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wo'
# '0wo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wp'
# '0wp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wq'
# '0wq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wr'
# '0wr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ws'
# '0ws' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wt'
# '0wt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wu'
# '0wu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wv'
# '0wv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ww'
# '0ww' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wx'
# '0wx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wy'
# '0wy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0wz'
# '0wz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w0'
# '0w0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w1'
# '0w1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w2'
# '0w2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w3'
# '0w3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w4'
# '0w4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w5'
# '0w5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w6'
# '0w6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w7'
# '0w7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w8'
# '0w8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0w9'
# '0w9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xa'
# '0xa' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xb'
# '0xb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xc'
# '0xc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xd'
# '0xd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xe'
# '0xe' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xf'
# '0xf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xg'
# '0xg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xh'
# '0xh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xi'
# '0xi' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xj'
# '0xj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xk'
# '0xk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xl'
# '0xl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xm'
# '0xm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xn'
# '0xn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xo'
# '0xo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xp'
# '0xp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xq'
# '0xq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xr'
# '0xr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xs'
# '0xs' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xt'
# '0xt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xu'
# '0xu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xv'
# '0xv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xw'
# '0xw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xx'
# '0xx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xy'
# '0xy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0xz'
# '0xz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x0'
# '0x0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x1'
# '0x1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x2'
# '0x2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x3'
# '0x3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x4'
# '0x4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x5'
# '0x5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x6'
# '0x6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x7'
# '0x7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x8'
# '0x8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0x9'
# '0x9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ya'
# '0ya' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yb'
# '0yb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yc'
# '0yc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yd'
# '0yd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ye'
# '0ye' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yf'
# '0yf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yg'
# '0yg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yh'
# '0yh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yi'
# '0yi' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yj'
# '0yj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yk'
# '0yk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yl'
# '0yl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ym'
# '0ym' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yn'
# '0yn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yo'
# '0yo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yp'
# '0yp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yq'
# '0yq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yr'
# '0yr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ys'
# '0ys' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yt'
# '0yt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yu'
# '0yu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yv'
# '0yv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yw'
# '0yw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yx'
# '0yx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yy'
# '0yy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0yz'
# '0yz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y0'
# '0y0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y1'
# '0y1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y2'
# '0y2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y3'
# '0y3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y4'
# '0y4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y5'
# '0y5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y6'
# '0y6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y7'
# '0y7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y8'
# '0y8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0y9'
# '0y9' is not the correct password
#
# Trying to extract 'b.zip' with the password '0za'
# '0za' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zb'
# '0zb' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zc'
# '0zc' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zd'
# '0zd' is not the correct password
#
# Trying to extract 'b.zip' with the password '0ze'
# '0ze' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zf'
# '0zf' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zg'
# '0zg' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zh'
# '0zh' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zi'
# '0zi' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zj'
# '0zj' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zk'
# '0zk' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zl'
# '0zl' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zm'
# '0zm' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zn'
# '0zn' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zo'
# '0zo' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zp'
# '0zp' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zq'
# '0zq' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zr'
# '0zr' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zs'
# '0zs' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zt'
# '0zt' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zu'
# '0zu' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zv'
# '0zv' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zw'
# '0zw' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zx'
# '0zx' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zy'
# '0zy' is not the correct password
#
# Trying to extract 'b.zip' with the password '0zz'
# '0zz' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z0'
# '0z0' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z1'
# '0z1' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z2'
# '0z2' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z3'
# '0z3' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z4'
# '0z4' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z5'
# '0z5' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z6'
# '0z6' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z7'
# '0z7' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z8'
# '0z8' is not the correct password
#
# Trying to extract 'b.zip' with the password '0z9'
# '0z9' is not the correct password
#
# Trying to extract 'b.zip' with the password '00a'
# '00a' is not the correct password
#
# Trying to extract 'b.zip' with the password '00b'
# '00b' is not the correct password
#
# Trying to extract 'b.zip' with the password '00c'
# '00c' is not the correct password
#
# Trying to extract 'b.zip' with the password '00d'
# '00d' is not the correct password
#
# Trying to extract 'b.zip' with the password '00e'
# '00e' is not the correct password
#
# Trying to extract 'b.zip' with the password '00f'
# '00f' is not the correct password
#
# Trying to extract 'b.zip' with the password '00g'
# '00g' is not the correct password
#
# Trying to extract 'b.zip' with the password '00h'
# '00h' is not the correct password
#
# Trying to extract 'b.zip' with the password '00i'
# '00i' is not the correct password
#
# Trying to extract 'b.zip' with the password '00j'
# '00j' is not the correct password
#
# Trying to extract 'b.zip' with the password '00k'
# '00k' is not the correct password
#
# Trying to extract 'b.zip' with the password '00l'
# '00l' is not the correct password
#
# Trying to extract 'b.zip' with the password '00m'
# '00m' is not the correct password
#
# Trying to extract 'b.zip' with the password '00n'
# '00n' is not the correct password
#
# Trying to extract 'b.zip' with the password '00o'
# '00o' is not the correct password
#
# Trying to extract 'b.zip' with the password '00p'
# '00p' is not the correct password
#
# Trying to extract 'b.zip' with the password '00q'
# '00q' is not the correct password
#
# Trying to extract 'b.zip' with the password '00r'
# '00r' is not the correct password
#
# Trying to extract 'b.zip' with the password '00s'
# '00s' is not the correct password
#
# Trying to extract 'b.zip' with the password '00t'
# '00t' is not the correct password
#
# Trying to extract 'b.zip' with the password '00u'
# '00u' is not the correct password
#
# Trying to extract 'b.zip' with the password '00v'
# '00v' is not the correct password
#
# Trying to extract 'b.zip' with the password '00w'
# '00w' is not the correct password
#
# Trying to extract 'b.zip' with the password '00x'
# '00x' is not the correct password
#
# Trying to extract 'b.zip' with the password '00y'
# '00y' is not the correct password
#
# Trying to extract 'b.zip' with the password '00z'
# '00z' is not the correct password
#
# Trying to extract 'b.zip' with the password '000'
# '000' is not the correct password
#
# Trying to extract 'b.zip' with the password '001'
# '001' is not the correct password
#
# Trying to extract 'b.zip' with the password '002'
# '002' is not the correct password
#
# Trying to extract 'b.zip' with the password '003'
# '003' is not the correct password
#
# Trying to extract 'b.zip' with the password '004'
# '004' is not the correct password
#
# Trying to extract 'b.zip' with the password '005'
# '005' is not the correct password
#
# Trying to extract 'b.zip' with the password '006'
# '006' is not the correct password
#
# Trying to extract 'b.zip' with the password '007'
# '007' is not the correct password
#
# Trying to extract 'b.zip' with the password '008'
# '008' is not the correct password
#
# Trying to extract 'b.zip' with the password '009'
# '009' is not the correct password
#
# Trying to extract 'b.zip' with the password '01a'
# '01a' is not the correct password
#
# Trying to extract 'b.zip' with the password '01b'
# '01b' is not the correct password
#
# Trying to extract 'b.zip' with the password '01c'
# '01c' is not the correct password
#
# Trying to extract 'b.zip' with the password '01d'
# '01d' is not the correct password
#
# Trying to extract 'b.zip' with the password '01e'
# '01e' is not the correct password
#
# Trying to extract 'b.zip' with the password '01f'
# '01f' is not the correct password
#
# Trying to extract 'b.zip' with the password '01g'
# '01g' is not the correct password
#
# Trying to extract 'b.zip' with the password '01h'
# '01h' is not the correct password
#
# Trying to extract 'b.zip' with the password '01i'
# '01i' is not the correct password
#
# Trying to extract 'b.zip' with the password '01j'
# '01j' is not the correct password
#
# Trying to extract 'b.zip' with the password '01k'
# '01k' is not the correct password
#
# Trying to extract 'b.zip' with the password '01l'
# '01l' is not the correct password
#
# Trying to extract 'b.zip' with the password '01m'
# '01m' is not the correct password
#
# Trying to extract 'b.zip' with the password '01n'
# '01n' is not the correct password
#
# Trying to extract 'b.zip' with the password '01o'
# '01o' is not the correct password
#
# Trying to extract 'b.zip' with the password '01p'
# '01p' is not the correct password
#
# Trying to extract 'b.zip' with the password '01q'
# '01q' is not the correct password
#
# Trying to extract 'b.zip' with the password '01r'
# '01r' is not the correct password
#
# Trying to extract 'b.zip' with the password '01s'
# '01s' is not the correct password
#
# Trying to extract 'b.zip' with the password '01t'
# '01t' is not the correct password
#
# Trying to extract 'b.zip' with the password '01u'
# '01u' is not the correct password
#
# Trying to extract 'b.zip' with the password '01v'
# '01v' is not the correct password
#
# Trying to extract 'b.zip' with the password '01w'
# '01w' is not the correct password
#
# Trying to extract 'b.zip' with the password '01x'
# '01x' is not the correct password
#
# Trying to extract 'b.zip' with the password '01y'
# '01y' is not the correct password
#
# Trying to extract 'b.zip' with the password '01z'
# '01z' is not the correct password
#
# Trying to extract 'b.zip' with the password '010'
# '010' is not the correct password
#
# Trying to extract 'b.zip' with the password '011'
# '011' is not the correct password
#
# Trying to extract 'b.zip' with the password '012'
# '012' is not the correct password
#
# Trying to extract 'b.zip' with the password '013'
# '013' is not the correct password
#
# Trying to extract 'b.zip' with the password '014'
# '014' is not the correct password
#
# Trying to extract 'b.zip' with the password '015'
# '015' is not the correct password
#
# Trying to extract 'b.zip' with the password '016'
# '016' is not the correct password
#
# Trying to extract 'b.zip' with the password '017'
# '017' is not the correct password
#
# Trying to extract 'b.zip' with the password '018'
# '018' is not the correct password
#
# Trying to extract 'b.zip' with the password '019'
# '019' is not the correct password
#
# Trying to extract 'b.zip' with the password '02a'
# '02a' is not the correct password
#
# Trying to extract 'b.zip' with the password '02b'
# '02b' is not the correct password
#
# Trying to extract 'b.zip' with the password '02c'
# '02c' is not the correct password
#
# Trying to extract 'b.zip' with the password '02d'
# '02d' is not the correct password
#
# Trying to extract 'b.zip' with the password '02e'
# '02e' is not the correct password
#
# Trying to extract 'b.zip' with the password '02f'
# '02f' is not the correct password
#
# Trying to extract 'b.zip' with the password '02g'
# '02g' is not the correct password
#
# Trying to extract 'b.zip' with the password '02h'
# '02h' is not the correct password
#
# Trying to extract 'b.zip' with the password '02i'
# '02i' is not the correct password
#
# Trying to extract 'b.zip' with the password '02j'
# '02j' is not the correct password
#
# Trying to extract 'b.zip' with the password '02k'
# '02k' is not the correct password
#
# Trying to extract 'b.zip' with the password '02l'
# '02l' is not the correct password
#
# Trying to extract 'b.zip' with the password '02m'
# '02m' is not the correct password
#
# Trying to extract 'b.zip' with the password '02n'
# '02n' is not the correct password
#
# Trying to extract 'b.zip' with the password '02o'
# '02o' is not the correct password
#
# Trying to extract 'b.zip' with the password '02p'
# '02p' is not the correct password
#
# Trying to extract 'b.zip' with the password '02q'
# '02q' is not the correct password
#
# Trying to extract 'b.zip' with the password '02r'
# '02r' is not the correct password
#
# Trying to extract 'b.zip' with the password '02s'
# '02s' is not the correct password
#
# Trying to extract 'b.zip' with the password '02t'
# '02t' is not the correct password
#
# Trying to extract 'b.zip' with the password '02u'
# '02u' is not the correct password
#
# Trying to extract 'b.zip' with the password '02v'
# '02v' is not the correct password
#
# Trying to extract 'b.zip' with the password '02w'
# '02w' is not the correct password
#
# Trying to extract 'b.zip' with the password '02x'
# '02x' is not the correct password
#
# Trying to extract 'b.zip' with the password '02y'
# '02y' is not the correct password
#
# Trying to extract 'b.zip' with the password '02z'
# '02z' is not the correct password
#
# Trying to extract 'b.zip' with the password '020'
# '020' is not the correct password
#
# Trying to extract 'b.zip' with the password '021'
# '021' is not the correct password
#
# Trying to extract 'b.zip' with the password '022'
# '022' is not the correct password
#
# Trying to extract 'b.zip' with the password '023'
# '023' is not the correct password
#
# Trying to extract 'b.zip' with the password '024'
# '024' is not the correct password
#
# Trying to extract 'b.zip' with the password '025'
# '025' is not the correct password
#
# Trying to extract 'b.zip' with the password '026'
# '026' is not the correct password
#
# Trying to extract 'b.zip' with the password '027'
# '027' is not the correct password
#
# Trying to extract 'b.zip' with the password '028'
# '028' is not the correct password
#
# Trying to extract 'b.zip' with the password '029'
# '029' is not the correct password
#
# Trying to extract 'b.zip' with the password '03a'
# '03a' is not the correct password
#
# Trying to extract 'b.zip' with the password '03b'
# '03b' is not the correct password
#
# Trying to extract 'b.zip' with the password '03c'
# '03c' is not the correct password
#
# Trying to extract 'b.zip' with the password '03d'
# '03d' is not the correct password
#
# Trying to extract 'b.zip' with the password '03e'
# '03e' is not the correct password
#
# Trying to extract 'b.zip' with the password '03f'
# '03f' is not the correct password
#
# Trying to extract 'b.zip' with the password '03g'
# '03g' is not the correct password
#
# Trying to extract 'b.zip' with the password '03h'
# '03h' is not the correct password
#
# Trying to extract 'b.zip' with the password '03i'
# '03i' is not the correct password
#
# Trying to extract 'b.zip' with the password '03j'
# '03j' is not the correct password
#
# Trying to extract 'b.zip' with the password '03k'
# '03k' is not the correct password
#
# Trying to extract 'b.zip' with the password '03l'
# '03l' is not the correct password
#
# Trying to extract 'b.zip' with the password '03m'
# '03m' is not the correct password
#
# Trying to extract 'b.zip' with the password '03n'
# '03n' is not the correct password
#
# Trying to extract 'b.zip' with the password '03o'
# '03o' is not the correct password
#
# Trying to extract 'b.zip' with the password '03p'
# '03p' is not the correct password
#
# Trying to extract 'b.zip' with the password '03q'
# '03q' is not the correct password
#
# Trying to extract 'b.zip' with the password '03r'
# '03r' is not the correct password
#
# Trying to extract 'b.zip' with the password '03s'
# '03s' is not the correct password
#
# Trying to extract 'b.zip' with the password '03t'
# '03t' is not the correct password
#
# Trying to extract 'b.zip' with the password '03u'
# '03u' is not the correct password
#
# Trying to extract 'b.zip' with the password '03v'
# '03v' is not the correct password
#
# Trying to extract 'b.zip' with the password '03w'
# '03w' is not the correct password
#
# Trying to extract 'b.zip' with the password '03x'
# '03x' is not the correct password
#
# Trying to extract 'b.zip' with the password '03y'
# '03y' is not the correct password
#
# Trying to extract 'b.zip' with the password '03z'
# '03z' is not the correct password
#
# Trying to extract 'b.zip' with the password '030'
# '030' is not the correct password
#
# Trying to extract 'b.zip' with the password '031'
# '031' is not the correct password
#
# Trying to extract 'b.zip' with the password '032'
# '032' is not the correct password
#
# Trying to extract 'b.zip' with the password '033'
# '033' is not the correct password
#
# Trying to extract 'b.zip' with the password '034'
# '034' is not the correct password
#
# Trying to extract 'b.zip' with the password '035'
# '035' is not the correct password
#
# Trying to extract 'b.zip' with the password '036'
# '036' is not the correct password
#
# Trying to extract 'b.zip' with the password '037'
# '037' is not the correct password
#
# Trying to extract 'b.zip' with the password '038'
# '038' is not the correct password
#
# Trying to extract 'b.zip' with the password '039'
# '039' is not the correct password
#
# Trying to extract 'b.zip' with the password '04a'
# '04a' is not the correct password
#
# Trying to extract 'b.zip' with the password '04b'
# '04b' is not the correct password
#
# Trying to extract 'b.zip' with the password '04c'
# '04c' is not the correct password
#
# Trying to extract 'b.zip' with the password '04d'
# '04d' is not the correct password
#
# Trying to extract 'b.zip' with the password '04e'
# '04e' is not the correct password
#
# Trying to extract 'b.zip' with the password '04f'
# '04f' is not the correct password
#
# Trying to extract 'b.zip' with the password '04g'
# '04g' is not the correct password
#
# Trying to extract 'b.zip' with the password '04h'
# '04h' is not the correct password
#
# Trying to extract 'b.zip' with the password '04i'
# '04i' is not the correct password
#
# Trying to extract 'b.zip' with the password '04j'
# '04j' is not the correct password
#
# Trying to extract 'b.zip' with the password '04k'
# '04k' is not the correct password
#
# Trying to extract 'b.zip' with the password '04l'
# '04l' is not the correct password
#
# Trying to extract 'b.zip' with the password '04m'
# '04m' is not the correct password
#
# Trying to extract 'b.zip' with the password '04n'
# '04n' is not the correct password
#
# Trying to extract 'b.zip' with the password '04o'
# '04o' is not the correct password
#
# Trying to extract 'b.zip' with the password '04p'
# '04p' is not the correct password
#
# Trying to extract 'b.zip' with the password '04q'
# '04q' is not the correct password
#
# Trying to extract 'b.zip' with the password '04r'
# '04r' is not the correct password
#
# Trying to extract 'b.zip' with the password '04s'
# '04s' is not the correct password
#
# Trying to extract 'b.zip' with the password '04t'
# '04t' is not the correct password
#
# Trying to extract 'b.zip' with the password '04u'
# '04u' is not the correct password
#
# Trying to extract 'b.zip' with the password '04v'
# '04v' is not the correct password
#
# Trying to extract 'b.zip' with the password '04w'
# '04w' is not the correct password
#
# Trying to extract 'b.zip' with the password '04x'
# '04x' is not the correct password
#
# Trying to extract 'b.zip' with the password '04y'
# '04y' is not the correct password
#
# Trying to extract 'b.zip' with the password '04z'
# '04z' is not the correct password
#
# Trying to extract 'b.zip' with the password '040'
# '040' is not the correct password
#
# Trying to extract 'b.zip' with the password '041'
# '041' is not the correct password
#
# Trying to extract 'b.zip' with the password '042'
# '042' is not the correct password
#
# Trying to extract 'b.zip' with the password '043'
# '043' is not the correct password
#
# Trying to extract 'b.zip' with the password '044'
# '044' is not the correct password
#
# Trying to extract 'b.zip' with the password '045'
# '045' is not the correct password
#
# Trying to extract 'b.zip' with the password '046'
# '046' is not the correct password
#
# Trying to extract 'b.zip' with the password '047'
# '047' is not the correct password
#
# Trying to extract 'b.zip' with the password '048'
# '048' is not the correct password
#
# Trying to extract 'b.zip' with the password '049'
# '049' is not the correct password
#
# Trying to extract 'b.zip' with the password '05a'
# '05a' is not the correct password
#
# Trying to extract 'b.zip' with the password '05b'
# '05b' is not the correct password
#
# Trying to extract 'b.zip' with the password '05c'
# '05c' is not the correct password
#
# Trying to extract 'b.zip' with the password '05d'
# '05d' is not the correct password
#
# Trying to extract 'b.zip' with the password '05e'
# '05e' is not the correct password
#
# Trying to extract 'b.zip' with the password '05f'
# '05f' is not the correct password
#
# Trying to extract 'b.zip' with the password '05g'
# '05g' is not the correct password
#
# Trying to extract 'b.zip' with the password '05h'
# '05h' is not the correct password
#
# Trying to extract 'b.zip' with the password '05i'
# '05i' is not the correct password
#
# Trying to extract 'b.zip' with the password '05j'
# '05j' is not the correct password
#
# Trying to extract 'b.zip' with the password '05k'
# '05k' is not the correct password
#
# Trying to extract 'b.zip' with the password '05l'
# '05l' is not the correct password
#
# Trying to extract 'b.zip' with the password '05m'
# '05m' is not the correct password
#
# Trying to extract 'b.zip' with the password '05n'
# '05n' is not the correct password
#
# Trying to extract 'b.zip' with the password '05o'
# '05o' is not the correct password
#
# Trying to extract 'b.zip' with the password '05p'
# '05p' is not the correct password
#
# Trying to extract 'b.zip' with the password '05q'
# '05q' is not the correct password
#
# Trying to extract 'b.zip' with the password '05r'
# '05r' is not the correct password
#
# Trying to extract 'b.zip' with the password '05s'
# '05s' is not the correct password
#
# Trying to extract 'b.zip' with the password '05t'
# '05t' is not the correct password
#
# Trying to extract 'b.zip' with the password '05u'
# '05u' is not the correct password
#
# Trying to extract 'b.zip' with the password '05v'
# '05v' is not the correct password
#
# Trying to extract 'b.zip' with the password '05w'
# '05w' is not the correct password
#
# Trying to extract 'b.zip' with the password '05x'
# '05x' is not the correct password
#
# Trying to extract 'b.zip' with the password '05y'
# '05y' is not the correct password
#
# Trying to extract 'b.zip' with the password '05z'
# '05z' is not the correct password
#
# Trying to extract 'b.zip' with the password '050'
# '050' is not the correct password
#
# Trying to extract 'b.zip' with the password '051'
# '051' is not the correct password
#
# Trying to extract 'b.zip' with the password '052'
# '052' is not the correct password
#
# Trying to extract 'b.zip' with the password '053'
# '053' is not the correct password
#
# Trying to extract 'b.zip' with the password '054'
# '054' is not the correct password
#
# Trying to extract 'b.zip' with the password '055'
# '055' is not the correct password
#
# Trying to extract 'b.zip' with the password '056'
# '056' is not the correct password
#
# Trying to extract 'b.zip' with the password '057'
# '057' is not the correct password
#
# Trying to extract 'b.zip' with the password '058'
# '058' is not the correct password
#
# Trying to extract 'b.zip' with the password '059'
# '059' is not the correct password
#
# Trying to extract 'b.zip' with the password '06a'
# '06a' is not the correct password
#
# Trying to extract 'b.zip' with the password '06b'
# '06b' is not the correct password
#
# Trying to extract 'b.zip' with the password '06c'
# '06c' is not the correct password
#
# Trying to extract 'b.zip' with the password '06d'
# '06d' is not the correct password
#
# Trying to extract 'b.zip' with the password '06e'
# '06e' is not the correct password
#
# Trying to extract 'b.zip' with the password '06f'
# '06f' is not the correct password
#
# Trying to extract 'b.zip' with the password '06g'
# ...
#
# Trying to extract 'b.zip' with the password '1vt'
# '1vt' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vu'
# '1vu' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vv'
# '1vv' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vw'
# '1vw' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vx'
# '1vx' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vy'
# '1vy' is not the correct password
#
# Trying to extract 'b.zip' with the password '1vz'
# '1vz' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v0'
# '1v0' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v1'
# '1v1' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v2'
# '1v2' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v3'
# '1v3' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v4'
# '1v4' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v5'
# '1v5' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v6'
# '1v6' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v7'
# '1v7' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v8'
# '1v8' is not the correct password
#
# Trying to extract 'b.zip' with the password '1v9'
# '1v9' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wa'
# '1wa' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wb'
# '1wb' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wc'
# '1wc' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wd'
# '1wd' is not the correct password
#
# Trying to extract 'b.zip' with the password '1we'
# '1we' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wf'
# '1wf' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wg'
# '1wg' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wh'
# '1wh' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wi'
# '1wi' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wj'
# '1wj' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wk'
# '1wk' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wl'
# '1wl' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wm'
# '1wm' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wn'
# '1wn' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wo'
# '1wo' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wp'
# '1wp' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wq'
# '1wq' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wr'
# '1wr' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ws'
# '1ws' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wt'
# '1wt' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wu'
# '1wu' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wv'
# '1wv' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ww'
# '1ww' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wx'
# '1wx' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wy'
# '1wy' is not the correct password
#
# Trying to extract 'b.zip' with the password '1wz'
# '1wz' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w0'
# '1w0' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w1'
# '1w1' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w2'
# '1w2' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w3'
# '1w3' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w4'
# '1w4' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w5'
# '1w5' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w6'
# '1w6' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w7'
# '1w7' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w8'
# '1w8' is not the correct password
#
# Trying to extract 'b.zip' with the password '1w9'
# '1w9' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xa'
# '1xa' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xb'
# '1xb' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xc'
# '1xc' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xd'
# '1xd' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xe'
# '1xe' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xf'
# '1xf' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xg'
# '1xg' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xh'
# '1xh' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xi'
# '1xi' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xj'
# '1xj' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xk'
# '1xk' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xl'
# '1xl' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xm'
# '1xm' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xn'
# '1xn' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xo'
# '1xo' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xp'
# '1xp' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xq'
# '1xq' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xr'
# '1xr' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xs'
# '1xs' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xt'
# '1xt' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xu'
# '1xu' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xv'
# '1xv' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xw'
# '1xw' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xx'
# '1xx' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xy'
# '1xy' is not the correct password
#
# Trying to extract 'b.zip' with the password '1xz'
# '1xz' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x0'
# '1x0' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x1'
# '1x1' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x2'
# '1x2' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x3'
# '1x3' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x4'
# '1x4' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x5'
# '1x5' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x6'
# '1x6' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x7'
# '1x7' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x8'
# '1x8' is not the correct password
#
# Trying to extract 'b.zip' with the password '1x9'
# '1x9' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ya'
# '1ya' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yb'
# '1yb' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yc'
# '1yc' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yd'
# '1yd' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ye'
# '1ye' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yf'
# '1yf' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yg'
# '1yg' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yh'
# '1yh' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yi'
# '1yi' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yj'
# '1yj' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yk'
# '1yk' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yl'
# '1yl' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ym'
# '1ym' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yn'
# '1yn' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yo'
# '1yo' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yp'
# '1yp' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yq'
# '1yq' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yr'
# '1yr' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ys'
# '1ys' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yt'
# '1yt' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yu'
# '1yu' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yv'
# '1yv' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yw'
# '1yw' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yx'
# '1yx' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yy'
# '1yy' is not the correct password
#
# Trying to extract 'b.zip' with the password '1yz'
# '1yz' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y0'
# '1y0' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y1'
# '1y1' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y2'
# '1y2' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y3'
# '1y3' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y4'
# '1y4' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y5'
# '1y5' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y6'
# '1y6' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y7'
# '1y7' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y8'
# '1y8' is not the correct password
#
# Trying to extract 'b.zip' with the password '1y9'
# '1y9' is not the correct password
#
# Trying to extract 'b.zip' with the password '1za'
# '1za' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zb'
# '1zb' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zc'
# '1zc' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zd'
# '1zd' is not the correct password
#
# Trying to extract 'b.zip' with the password '1ze'
# '1ze' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zf'
# '1zf' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zg'
# '1zg' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zh'
# '1zh' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zi'
# '1zi' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zj'
# '1zj' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zk'
# '1zk' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zl'
# '1zl' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zm'
# '1zm' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zn'
# '1zn' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zo'
# '1zo' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zp'
# '1zp' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zq'
# '1zq' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zr'
# '1zr' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zs'
# '1zs' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zt'
# '1zt' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zu'
# '1zu' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zv'
# '1zv' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zw'
# '1zw' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zx'
# '1zx' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zy'
# '1zy' is not the correct password
#
# Trying to extract 'b.zip' with the password '1zz'
# '1zz' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z0'
# '1z0' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z1'
# '1z1' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z2'
# '1z2' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z3'
# '1z3' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z4'
# '1z4' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z5'
# '1z5' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z6'
# '1z6' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z7'
# '1z7' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z8'
# '1z8' is not the correct password
#
# Trying to extract 'b.zip' with the password '1z9'
# '1z9' is not the correct password
#
# Trying to extract 'b.zip' with the password '10a'
# '10a' is not the correct password
#
# Trying to extract 'b.zip' with the password '10b'
# '10b' is not the correct password
#
# Trying to extract 'b.zip' with the password '10c'
# '10c' is not the correct password
#
# Trying to extract 'b.zip' with the password '10d'
# '10d' is not the correct password
#
# Trying to extract 'b.zip' with the password '10e'
# '10e' is not the correct password
#
# Trying to extract 'b.zip' with the password '10f'
# '10f' is not the correct password
#
# Trying to extract 'b.zip' with the password '10g'
# '10g' is not the correct password
#
# Trying to extract 'b.zip' with the password '10h'
# '10h' is not the correct password
#
# Trying to extract 'b.zip' with the password '10i'
# '10i' is not the correct password
#
# Trying to extract 'b.zip' with the password '10j'
# '10j' is not the correct password
#
# Trying to extract 'b.zip' with the password '10k'
# '10k' is not the correct password
#
# Trying to extract 'b.zip' with the password '10l'
# '10l' is not the correct password
#
# Trying to extract 'b.zip' with the password '10m'
# '10m' is not the correct password
#
# Trying to extract 'b.zip' with the password '10n'
# '10n' is not the correct password
#
# Trying to extract 'b.zip' with the password '10o'
# '10o' is not the correct password
#
# Trying to extract 'b.zip' with the password '10p'
# '10p' is not the correct password
#
# Trying to extract 'b.zip' with the password '10q'
# '10q' is not the correct password
#
# Trying to extract 'b.zip' with the password '10r'
# '10r' is not the correct password
#
# Trying to extract 'b.zip' with the password '10s'
# '10s' is not the correct password
#
# Trying to extract 'b.zip' with the password '10t'
# '10t' is not the correct password
#
# Trying to extract 'b.zip' with the password '10u'
# '10u' is not the correct password
#
# Trying to extract 'b.zip' with the password '10v'
# '10v' is not the correct password
#
# Trying to extract 'b.zip' with the password '10w'
# '10w' is not the correct password
#
# Trying to extract 'b.zip' with the password '10x'
# '10x' is not the correct password
#
# Trying to extract 'b.zip' with the password '10y'
# '10y' is not the correct password
#
# Trying to extract 'b.zip' with the password '10z'
# '10z' is not the correct password
#
# Trying to extract 'b.zip' with the password '100'
#
#
# The correct password is '100'.
#
#
# End.......

# %%
import zipfile
import itertools
import string

print("\n\nStart.........\n\n")

# Create a list of characters to use in the password
characters = string.ascii_lowercase + string.digits

# Define the ZIP file to be opened
zip_file_path = 'c.zip'

# Function to generate all possible passwords
def generate_passwords(max_length):
    for length in range(1, max_length + 1):
        for password in itertools.product(characters, repeat=length):
            yield ''.join(password)

# Open the ZIP file
with zipfile.ZipFile(zip_file_path) as the_zip_package:
    found_password = False
    for current_password in generate_passwords(6):
        try:
            print(f"Trying to extract '{the_zip_package.filename}' with the password '{current_password}'")
            the_zip_package.extractall(pwd=current_password.encode())
            found_password = True
            print(f"\n\nThe correct password is '{current_password}'.")
            break
        except (RuntimeError, zipfile.BadZipFile) as e:
            print(f"'{current_password}' is not the correct password", end='\n\n')

    if not found_password:
        print("\n\nNone of the generated passwords is correct.")

print("\n\nEnd.......\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# 'b37' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b38'
# 'b38' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b39'
# 'b39' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4a'
# 'b4a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4b'
# 'b4b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4c'
# 'b4c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4d'
# 'b4d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4e'
# 'b4e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4f'
# 'b4f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4g'
# 'b4g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4h'
# 'b4h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4i'
# 'b4i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4j'
# 'b4j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4k'
# 'b4k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4l'
# 'b4l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4m'
# 'b4m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4n'
# 'b4n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4o'
# 'b4o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4p'
# 'b4p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4q'
# 'b4q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4r'
# 'b4r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4s'
# 'b4s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4t'
# 'b4t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4u'
# 'b4u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4v'
# 'b4v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4w'
# 'b4w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4x'
# 'b4x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4y'
# 'b4y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b4z'
# 'b4z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b40'
# 'b40' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b41'
# 'b41' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b42'
# 'b42' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b43'
# 'b43' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b44'
# 'b44' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b45'
# 'b45' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b46'
# 'b46' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b47'
# 'b47' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b48'
# 'b48' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b49'
# 'b49' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5a'
# 'b5a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5b'
# 'b5b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5c'
# 'b5c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5d'
# 'b5d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5e'
# 'b5e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5f'
# 'b5f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5g'
# 'b5g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5h'
# 'b5h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5i'
# 'b5i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5j'
# 'b5j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5k'
# 'b5k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5l'
# 'b5l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5m'
# 'b5m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5n'
# 'b5n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5o'
# 'b5o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5p'
# 'b5p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5q'
# 'b5q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5r'
# 'b5r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5s'
# 'b5s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5t'
# 'b5t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5u'
# 'b5u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5v'
# 'b5v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5w'
# 'b5w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5x'
# 'b5x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5y'
# 'b5y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b5z'
# 'b5z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b50'
# 'b50' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b51'
# 'b51' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b52'
# 'b52' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b53'
# 'b53' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b54'
# 'b54' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b55'
# 'b55' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b56'
# 'b56' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b57'
# 'b57' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b58'
# 'b58' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b59'
# 'b59' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6a'
# 'b6a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6b'
# 'b6b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6c'
# 'b6c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6d'
# 'b6d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6e'
# 'b6e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6f'
# 'b6f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6g'
# 'b6g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6h'
# 'b6h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6i'
# 'b6i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6j'
# 'b6j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6k'
# 'b6k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6l'
# 'b6l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6m'
# 'b6m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6n'
# 'b6n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6o'
# 'b6o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6p'
# 'b6p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6q'
# 'b6q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6r'
# 'b6r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6s'
# 'b6s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6t'
# 'b6t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6u'
# 'b6u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6v'
# 'b6v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6w'
# 'b6w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6x'
# 'b6x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6y'
# 'b6y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b6z'
# 'b6z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b60'
# 'b60' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b61'
# 'b61' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b62'
# 'b62' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b63'
# 'b63' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b64'
# 'b64' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b65'
# 'b65' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b66'
# 'b66' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b67'
# 'b67' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b68'
# 'b68' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b69'
# 'b69' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7a'
# 'b7a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7b'
# 'b7b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7c'
# 'b7c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7d'
# 'b7d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7e'
# 'b7e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7f'
# 'b7f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7g'
# 'b7g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7h'
# 'b7h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7i'
# 'b7i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7j'
# 'b7j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7k'
# 'b7k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7l'
# 'b7l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7m'
# 'b7m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7n'
# 'b7n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7o'
# 'b7o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7p'
# 'b7p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7q'
# 'b7q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7r'
# 'b7r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7s'
# 'b7s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7t'
# 'b7t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7u'
# 'b7u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7v'
# 'b7v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7w'
# 'b7w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7x'
# 'b7x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7y'
# 'b7y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b7z'
# 'b7z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b70'
# 'b70' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b71'
# 'b71' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b72'
# 'b72' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b73'
# 'b73' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b74'
# 'b74' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b75'
# 'b75' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b76'
# 'b76' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b77'
# 'b77' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b78'
# 'b78' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b79'
# 'b79' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8a'
# 'b8a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8b'
# 'b8b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8c'
# 'b8c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8d'
# 'b8d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8e'
# 'b8e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8f'
# 'b8f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8g'
# 'b8g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8h'
# 'b8h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8i'
# 'b8i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8j'
# 'b8j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8k'
# 'b8k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8l'
# 'b8l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8m'
# 'b8m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8n'
# 'b8n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8o'
# 'b8o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8p'
# 'b8p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8q'
# 'b8q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8r'
# 'b8r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8s'
# 'b8s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8t'
# 'b8t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8u'
# 'b8u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8v'
# 'b8v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8w'
# 'b8w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8x'
# 'b8x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8y'
# 'b8y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b8z'
# 'b8z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b80'
# 'b80' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b81'
# 'b81' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b82'
# 'b82' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b83'
# 'b83' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b84'
# 'b84' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b85'
# 'b85' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b86'
# 'b86' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b87'
# 'b87' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b88'
# 'b88' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b89'
# 'b89' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9a'
# 'b9a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9b'
# 'b9b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9c'
# 'b9c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9d'
# 'b9d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9e'
# 'b9e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9f'
# 'b9f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9g'
# 'b9g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9h'
# 'b9h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9i'
# 'b9i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9j'
# 'b9j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9k'
# 'b9k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9l'
# 'b9l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9m'
# 'b9m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9n'
# 'b9n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9o'
# 'b9o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9p'
# 'b9p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9q'
# 'b9q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9r'
# 'b9r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9s'
# 'b9s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9t'
# 'b9t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9u'
# 'b9u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9v'
# 'b9v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9w'
# 'b9w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9x'
# 'b9x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9y'
# 'b9y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b9z'
# 'b9z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b90'
# 'b90' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b91'
# 'b91' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b92'
# 'b92' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b93'
# 'b93' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b94'
# 'b94' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b95'
# 'b95' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b96'
# 'b96' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b97'
# 'b97' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b98'
# 'b98' is not the correct password
#
# Trying to extract 'c.zip' with the password 'b99'
# 'b99' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caa'
# 'caa' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cab'
# 'cab' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cac'
# 'cac' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cad'
# 'cad' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cae'
# 'cae' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caf'
# 'caf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cag'
# 'cag' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cah'
# 'cah' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cai'
# 'cai' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caj'
# 'caj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cak'
# 'cak' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cal'
# 'cal' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cam'
# 'cam' is not the correct password
#
# Trying to extract 'c.zip' with the password 'can'
# 'can' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cao'
# 'cao' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cap'
# 'cap' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caq'
# 'caq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'car'
# 'car' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cas'
# 'cas' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cat'
# 'cat' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cau'
# 'cau' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cav'
# 'cav' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caw'
# 'caw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cax'
# 'cax' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cay'
# 'cay' is not the correct password
#
# Trying to extract 'c.zip' with the password 'caz'
# 'caz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca0'
# 'ca0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca1'
# 'ca1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca2'
# 'ca2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca3'
# 'ca3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca4'
# 'ca4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca5'
# 'ca5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca6'
# 'ca6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca7'
# 'ca7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca8'
# 'ca8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ca9'
# 'ca9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cba'
# 'cba' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbb'
# 'cbb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbc'
# 'cbc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbd'
# 'cbd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbe'
# 'cbe' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbf'
# 'cbf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbg'
# 'cbg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbh'
# 'cbh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbi'
# 'cbi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbj'
# 'cbj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbk'
# 'cbk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbl'
# 'cbl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbm'
# 'cbm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbn'
# 'cbn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbo'
# 'cbo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbp'
# 'cbp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbq'
# 'cbq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbr'
# 'cbr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbs'
# 'cbs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbt'
# 'cbt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbu'
# 'cbu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbv'
# 'cbv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbw'
# 'cbw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbx'
# 'cbx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cby'
# 'cby' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cbz'
# 'cbz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb0'
# 'cb0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb1'
# 'cb1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb2'
# 'cb2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb3'
# 'cb3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb4'
# 'cb4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb5'
# 'cb5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb6'
# 'cb6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb7'
# 'cb7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb8'
# 'cb8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cb9'
# 'cb9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cca'
# 'cca' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccb'
# 'ccb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccc'
# 'ccc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccd'
# 'ccd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cce'
# 'cce' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccf'
# 'ccf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccg'
# 'ccg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cch'
# 'cch' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cci'
# 'cci' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccj'
# 'ccj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cck'
# 'cck' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccl'
# 'ccl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccm'
# 'ccm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccn'
# 'ccn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cco'
# 'cco' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccp'
# 'ccp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccq'
# 'ccq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccr'
# 'ccr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccs'
# 'ccs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cct'
# 'cct' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccu'
# 'ccu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccv'
# 'ccv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccw'
# 'ccw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccx'
# 'ccx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccy'
# 'ccy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ccz'
# 'ccz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc0'
# 'cc0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc1'
# 'cc1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc2'
# 'cc2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc3'
# 'cc3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc4'
# 'cc4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc5'
# 'cc5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc6'
# 'cc6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc7'
# 'cc7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc8'
# 'cc8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cc9'
# 'cc9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cda'
# 'cda' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdb'
# 'cdb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdc'
# 'cdc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdd'
# 'cdd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cde'
# 'cde' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdf'
# 'cdf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdg'
# 'cdg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdh'
# 'cdh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdi'
# 'cdi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdj'
# 'cdj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdk'
# 'cdk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdl'
# 'cdl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdm'
# 'cdm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdn'
# 'cdn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdo'
# 'cdo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdp'
# 'cdp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdq'
# 'cdq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdr'
# 'cdr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cds'
# 'cds' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdt'
# 'cdt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdu'
# 'cdu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdv'
# 'cdv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdw'
# 'cdw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdx'
# 'cdx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdy'
# 'cdy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cdz'
# 'cdz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd0'
# 'cd0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd1'
# 'cd1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd2'
# 'cd2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd3'
# 'cd3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd4'
# 'cd4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd5'
# 'cd5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd6'
# 'cd6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd7'
# 'cd7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd8'
# 'cd8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cd9'
# 'cd9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cea'
# 'cea' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceb'
# 'ceb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cec'
# 'cec' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ced'
# 'ced' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cee'
# 'cee' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cef'
# 'cef' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceg'
# 'ceg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceh'
# 'ceh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cei'
# 'cei' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cej'
# 'cej' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cek'
# 'cek' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cel'
# 'cel' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cem'
# 'cem' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cen'
# 'cen' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceo'
# 'ceo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cep'
# 'cep' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceq'
# 'ceq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cer'
# 'cer' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ces'
# 'ces' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cet'
# 'cet' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ceu'
# 'ceu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cev'
# 'cev' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cew'
# 'cew' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cex'
# 'cex' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cey'
# 'cey' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cez'
# 'cez' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce0'
# 'ce0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce1'
# 'ce1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce2'
# 'ce2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce3'
# 'ce3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce4'
# 'ce4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce5'
# 'ce5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce6'
# 'ce6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce7'
# 'ce7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce8'
# 'ce8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ce9'
# 'ce9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfa'
# 'cfa' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfb'
# 'cfb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfc'
# 'cfc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfd'
# 'cfd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfe'
# 'cfe' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cff'
# 'cff' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfg'
# 'cfg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfh'
# 'cfh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfi'
# 'cfi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfj'
# 'cfj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfk'
# 'cfk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfl'
# 'cfl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfm'
# 'cfm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfn'
# 'cfn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfo'
# 'cfo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfp'
# 'cfp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfq'
# 'cfq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfr'
# 'cfr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfs'
# 'cfs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cft'
# 'cft' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfu'
# 'cfu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfv'
# 'cfv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfw'
# 'cfw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfx'
# 'cfx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfy'
# 'cfy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cfz'
# 'cfz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf0'
# 'cf0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf1'
# 'cf1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf2'
# 'cf2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf3'
# 'cf3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf4'
# 'cf4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf5'
# 'cf5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf6'
# 'cf6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf7'
# 'cf7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf8'
# 'cf8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cf9'
# 'cf9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cga'
# 'cga' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgb'
# 'cgb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgc'
# 'cgc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgd'
# 'cgd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cge'
# 'cge' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgf'
# 'cgf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgg'
# 'cgg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgh'
# 'cgh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgi'
# 'cgi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgj'
# 'cgj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgk'
# 'cgk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgl'
# 'cgl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgm'
# 'cgm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgn'
# 'cgn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgo'
# 'cgo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgp'
# 'cgp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgq'
# 'cgq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgr'
# 'cgr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgs'
# 'cgs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgt'
# 'cgt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgu'
# 'cgu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgv'
# 'cgv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgw'
# 'cgw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgx'
# 'cgx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgy'
# 'cgy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cgz'
# 'cgz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg0'
# 'cg0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg1'
# 'cg1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg2'
# 'cg2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg3'
# 'cg3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg4'
# 'cg4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg5'
# 'cg5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg6'
# 'cg6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg7'
# 'cg7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg8'
# 'cg8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cg9'
# 'cg9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cha'
# 'cha' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chb'
# 'chb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chc'
# 'chc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chd'
# 'chd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'che'
# 'che' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chf'
# 'chf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chg'
# 'chg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chh'
# 'chh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chi'
# 'chi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chj'
# 'chj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chk'
# 'chk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chl'
# 'chl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chm'
# 'chm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chn'
# 'chn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cho'
# 'cho' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chp'
# 'chp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chq'
# 'chq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chr'
# 'chr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chs'
# 'chs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cht'
# 'cht' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chu'
# 'chu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chv'
# 'chv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chw'
# 'chw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chx'
# 'chx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chy'
# 'chy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'chz'
# 'chz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch0'
# 'ch0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch1'
# 'ch1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch2'
# 'ch2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch3'
# 'ch3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch4'
# 'ch4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch5'
# 'ch5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch6'
# 'ch6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch7'
# 'ch7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch8'
# 'ch8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ch9'
# 'ch9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cia'
# 'cia' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cib'
# 'cib' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cic'
# 'cic' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cid'
# 'cid' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cie'
# 'cie' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cif'
# 'cif' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cig'
# 'cig' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cih'
# 'cih' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cii'
# 'cii' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cij'
# 'cij' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cik'
# 'cik' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cil'
# 'cil' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cim'
# 'cim' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cin'
# 'cin' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cio'
# 'cio' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cip'
# 'cip' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ciq'
# 'ciq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cir'
# 'cir' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cis'
# 'cis' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cit'
# 'cit' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ciu'
# 'ciu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'civ'
# 'civ' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ciw'
# 'ciw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cix'
# 'cix' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ciy'
# 'ciy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ciz'
# 'ciz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci0'
# 'ci0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci1'
# 'ci1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci2'
# 'ci2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci3'
# 'ci3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci4'
# 'ci4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci5'
# 'ci5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci6'
# 'ci6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci7'
# 'ci7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci8'
# 'ci8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ci9'
# 'ci9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cja'
# 'cja' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjb'
# 'cjb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjc'
# 'cjc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjd'
# 'cjd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cje'
# 'cje' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjf'
# 'cjf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjg'
# 'cjg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjh'
# 'cjh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cji'
# 'cji' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjj'
# 'cjj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjk'
# 'cjk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjl'
# 'cjl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjm'
# 'cjm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjn'
# 'cjn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjo'
# 'cjo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjp'
# 'cjp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjq'
# 'cjq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjr'
# 'cjr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjs'
# 'cjs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjt'
# 'cjt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cju'
# 'cju' is not the correct password
#
# Trying to extract 'c.zip' with the password 'cjv'
# ...
#
# Trying to extract 'c.zip' with the password 'c88'
# 'c88' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c89'
# 'c89' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9a'
# 'c9a' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9b'
# 'c9b' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9c'
# 'c9c' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9d'
# 'c9d' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9e'
# 'c9e' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9f'
# 'c9f' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9g'
# 'c9g' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9h'
# 'c9h' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9i'
# 'c9i' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9j'
# 'c9j' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9k'
# 'c9k' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9l'
# 'c9l' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9m'
# 'c9m' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9n'
# 'c9n' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9o'
# 'c9o' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9p'
# 'c9p' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9q'
# 'c9q' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9r'
# 'c9r' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9s'
# 'c9s' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9t'
# 'c9t' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9u'
# 'c9u' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9v'
# 'c9v' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9w'
# 'c9w' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9x'
# 'c9x' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9y'
# 'c9y' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c9z'
# 'c9z' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c90'
# 'c90' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c91'
# 'c91' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c92'
# 'c92' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c93'
# 'c93' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c94'
# 'c94' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c95'
# 'c95' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c96'
# 'c96' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c97'
# 'c97' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c98'
# 'c98' is not the correct password
#
# Trying to extract 'c.zip' with the password 'c99'
# 'c99' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daa'
# 'daa' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dab'
# 'dab' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dac'
# 'dac' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dad'
# 'dad' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dae'
# 'dae' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daf'
# 'daf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dag'
# 'dag' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dah'
# 'dah' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dai'
# 'dai' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daj'
# 'daj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dak'
# 'dak' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dal'
# 'dal' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dam'
# 'dam' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dan'
# 'dan' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dao'
# 'dao' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dap'
# 'dap' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daq'
# 'daq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dar'
# 'dar' is not the correct password
#
# Trying to extract 'c.zip' with the password 'das'
# 'das' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dat'
# 'dat' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dau'
# 'dau' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dav'
# 'dav' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daw'
# 'daw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dax'
# 'dax' is not the correct password
#
# Trying to extract 'c.zip' with the password 'day'
# 'day' is not the correct password
#
# Trying to extract 'c.zip' with the password 'daz'
# 'daz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da0'
# 'da0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da1'
# 'da1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da2'
# 'da2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da3'
# 'da3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da4'
# 'da4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da5'
# 'da5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da6'
# 'da6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da7'
# 'da7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da8'
# 'da8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'da9'
# 'da9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dba'
# 'dba' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbb'
# 'dbb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbc'
# 'dbc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbd'
# 'dbd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbe'
# 'dbe' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbf'
# 'dbf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbg'
# 'dbg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbh'
# 'dbh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbi'
# 'dbi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbj'
# 'dbj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbk'
# 'dbk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbl'
# 'dbl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbm'
# 'dbm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbn'
# 'dbn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbo'
# 'dbo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbp'
# 'dbp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbq'
# 'dbq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbr'
# 'dbr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbs'
# 'dbs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbt'
# 'dbt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbu'
# 'dbu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbv'
# 'dbv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbw'
# 'dbw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbx'
# 'dbx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dby'
# 'dby' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dbz'
# 'dbz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db0'
# 'db0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db1'
# 'db1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db2'
# 'db2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db3'
# 'db3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db4'
# 'db4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db5'
# 'db5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db6'
# 'db6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db7'
# 'db7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db8'
# 'db8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'db9'
# 'db9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dca'
# 'dca' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcb'
# 'dcb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcc'
# 'dcc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcd'
# 'dcd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dce'
# 'dce' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcf'
# 'dcf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcg'
# 'dcg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dch'
# 'dch' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dci'
# 'dci' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcj'
# 'dcj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dck'
# 'dck' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcl'
# 'dcl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcm'
# 'dcm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcn'
# 'dcn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dco'
# 'dco' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcp'
# 'dcp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcq'
# 'dcq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcr'
# 'dcr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcs'
# 'dcs' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dct'
# 'dct' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcu'
# 'dcu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcv'
# 'dcv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcw'
# 'dcw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcx'
# 'dcx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcy'
# 'dcy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dcz'
# 'dcz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc0'
# 'dc0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc1'
# 'dc1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc2'
# 'dc2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc3'
# 'dc3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc4'
# 'dc4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc5'
# 'dc5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc6'
# 'dc6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc7'
# 'dc7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc8'
# 'dc8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dc9'
# 'dc9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dda'
# 'dda' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddb'
# 'ddb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddc'
# 'ddc' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddd'
# 'ddd' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dde'
# 'dde' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddf'
# 'ddf' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddg'
# 'ddg' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddh'
# 'ddh' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddi'
# 'ddi' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddj'
# 'ddj' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddk'
# 'ddk' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddl'
# 'ddl' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddm'
# 'ddm' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddn'
# 'ddn' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddo'
# 'ddo' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddp'
# 'ddp' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddq'
# 'ddq' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddr'
# 'ddr' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dds'
# 'dds' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddt'
# 'ddt' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddu'
# 'ddu' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddv'
# 'ddv' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddw'
# 'ddw' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddx'
# 'ddx' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddy'
# 'ddy' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ddz'
# 'ddz' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd0'
# 'dd0' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd1'
# 'dd1' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd2'
# 'dd2' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd3'
# 'dd3' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd4'
# 'dd4' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd5'
# 'dd5' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd6'
# 'dd6' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd7'
# 'dd7' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd8'
# 'dd8' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dd9'
# 'dd9' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dea'
# 'dea' is not the correct password
#
# Trying to extract 'c.zip' with the password 'deb'
# 'deb' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dec'
# 'dec' is not the correct password
#
# Trying to extract 'c.zip' with the password 'ded'
# 'ded' is not the correct password
#
# Trying to extract 'c.zip' with the password 'dee'
# 'dee' is not the correct password
#
# Trying to extract 'c.zip' with the password 'def'
#
#
# The correct password is 'def'.
#
#
# End.......
